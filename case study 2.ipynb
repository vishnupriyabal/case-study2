# %%
import pandas as pd
import numpy as np
data=pd.read_csv('StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # 1. No. of males and females participated in the test

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # 2. student's parental level of education

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(15,5))
data['parental level of education'].value_counts(normalize=True)
data['parental level of education'].value_counts(dropna=False).plot.bar(color=['yellow','green','black','blue','red'])
plt.title('Comparison of Parental Education')
plt.xlabel('Degree')
plt.ylabel('Count')
plt.show()

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# # 3.Who scores the most on average for math,reading and writing based on gender and tp course

# %%
ds=data.groupby(['gender','test preparation course'])[['reading score','math score','writing score']].mean()
ds
# Out:
#                                 reading score  math score  writing score
# gender test preparation course
# female completed                    77.375000   67.108696      78.793478
#        none                         69.955090   61.320359      68.982036
# male   completed                    70.793103   72.988506      70.339080
#        none                         62.581169   66.467532      59.551948

# %% [markdown]
# # 4.What do you think about the scoring variation for math,reading and writing based on gender and tp course

# %%
data.groupby(['gender','test preparation course']).agg(['min','median','max'])
# Out:
#                                math score             reading score         \
#                                       min median  max           min median
# gender test preparation course
# female completed                       23     67   99            40     78
#        none                             0     62  100            17     71
# male   completed                       39     74  100            37     72
#        none                            27     67   97            23     63
#
#                                     writing score
#                                 max           min median  max
# gender test preparation course
# female completed                100            36     79  100
#        none                     100            10     70  100
# male   completed                100            38     71  100
#        none                      96            15     60   92
